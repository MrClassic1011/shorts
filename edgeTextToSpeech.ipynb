# %%
import asyncio
import edge_tts

#hi-IN-MadhurNeural
#hi-IN-SwaraNeural
async def text_to_speech(text, voice='hi-IN-MadhurNeural'):
    try:
        communicate = edge_tts.Communicate(text, voice=voice)
        await communicate.save('output_hindi_male.mp3')  # Save as MP3
    except Exception as e:
        print(f"Error during text-to-speech conversion: {e}")

async def main():
    hindi_text = """
नमस्कार दोस्तों! आज हम बात करने वाले हैं एक ऐसे यूट्यूब शो की, जिसे आपमें से कई लोग शायद देख चुके होंगे। 
जी हां, हम बात कर रहे हैं समय रैना के शो 'INDIA'S GOT LATENT' की। इस शो में हमें हंसी और मज़ाक तो मिलती है, 
लेकिन कुछ चीज़ें हैं जो शायद आपको उतनी सही न लगी हों। आज हम इसी शो पर एक नज़र डालते हैं और जानते हैं कि 
इसमें क्या-क्या गलत हुआ।

पहली बात जो सबसे ज्यादा चुभी, वो थी पूनम पांडे और उनके OnlyFans कंटेंट पर गंदे जोक्स। भाई, कॉमेडी का मतलब हर 
किसी पर बेहूदा मज़ाक करना नहीं होता! पूनम पांडे के कंटेंट पर मज़ाक करके शो को पॉपुलर बनाने की कोशिश साफ नज़र आ रही थी। 
क्या ये सही तरीका है?

और मुंबई के लोगों पर भद्दे कमेंट्स? ये तो जैसे पूरे शहर का मज़ाक बना दिया। कॉमेडी तो होनी चाहिए, लेकिन ऐसी 
कॉमेडी जो सबको जोड़ दे, तोड़े नहीं। मुंबई को इस तरह टारगेट करके सस्ती लोकप्रियता पाना – ये शो का मकसद नहीं होना चाहिए था।

मधुरा जोशी, एक ऐसी गायिका जो अपना बेस्ट देने की कोशिश कर रही थीं, उन्हें साइको बुलाकर पूरी दुनिया के सामने 
बेइज्जत करना – भाई, ये किस तरह की कॉमेडी है? गाने का मजाक उड़ाना समझ आता है, लेकिन किसी की पर्सनैलिटी को 
इस तरह शेम करना?

और हद तो तब हो गई जब पूनम पांडे के OnlyFans कंटेंट को इंडायरेक्टली प्रोमोट किया गया। यूट्यूब एक ऐसा प्लेटफार्म है 
जहां हर उम्र के लोग आते हैं। क्या इस तरह का कंटेंट प्रोमोट करना सही है?

सागर, जिनकी मजबूत फिजिक पर बंदर चढ़ाई का मज़ाक उड़ाया गया – भाई, आप क्या करना चाह रहे थे? किसी की ताकत 
को यूं बदनाम करना एकदम नाइंसाफी है। और ये तो कुछ भी नहीं, जब बात लेओ बाबा की आई – जो पहले ही शारीरिक चुनौती 
का सामना कर रहे हैं – उनपर ऐसे मज़ाक करना पूरी तरह से गलत और अनएथिकल था। कॉमेडी की भी एक सीमा होती है!

और आखिर में, राख्षा तोमर, जिनको सिर्फ उनके शरीर की वजह से निशाना बनाया गया। उन्हें 'बड़ी बूब्स वाली लड़की' कहकर 
उनकी इंटेलिजेंस और पोएट्री स्किल्स पर सवाल उठाना – ये क्या मज़ाक है? कॉमेडी शो में, प्रतिभा को सराहा जाना चाहिए, 
न कि बुली किया जाना।

तो दोस्तों, यही थी हमारी बात समय रैना के शो 'INDIA'S GOT LATENT' पर। कॉमेडी को हंसाने के लिए किया जाना चाहिए, 
न कि किसी को नीचा दिखाने के लिए। अगर आपको भी लगता है कि कॉमेडी के नाम पर कुछ ज्यादा ही हो रहा है, तो नीचे 
कमेंट करके अपनी राय जरूर दें। वीडियो को लाइक करें और चैनल को subscribe करना न भूलें। मिलते हैं अगले वीडियो में। धन्यवाद!
"""
    await text_to_speech(hindi_text)

# Check if there's an existing event loop
try:
    asyncio.get_running_loop()
except RuntimeError:  # No running event loop
    asyncio.run(main())
else:  # There's a running event loop
    asyncio.create_task(main())
